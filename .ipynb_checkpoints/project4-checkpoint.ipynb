# %%
# %matplotlib inline
import statsmodels as ss
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
data = pd.read_csv('clean_weather_data.csv')
data.head()
# Out:
#           day  tempMin  tempMax                                  summary  \
# 0  2015-01-01     7.53    12.23       Possible light rain until evening.
# 1  2015-01-02     3.58     7.15  Possible light rain throughout the day.
# 2  2015-01-03    -0.61     6.54                Clear throughout the day.
# 3  2015-01-04    -0.63     7.59        Mostly cloudy throughout the day.
# 4  2015-01-05     6.51    10.43             Overcast throughout the day.
#
#                 desc  cloudCover  humidity  windSpeed  visibility
# 0               rain        0.80      0.89      14.69        4.43
# 1               rain        0.62      0.79      15.04        5.64
# 2               rain        0.31      0.84       4.48        6.20
# 3  partly-cloudy-day        0.78      0.85       4.35        6.22
# 4  partly-cloudy-day        0.85      0.91       6.20        5.91

# %%
data.shape
# Out:
# (1795, 9)

# %%
data['Month']=pd.to_datetime(data['day'])
data.set_index('Month',inplace=True)

# %%
data.head()
# Out:
#                    day  tempMin  tempMax  \
# Month
# 2015-01-01  2015-01-01     7.53    12.23
# 2015-01-02  2015-01-02     3.58     7.15
# 2015-01-03  2015-01-03    -0.61     6.54
# 2015-01-04  2015-01-04    -0.63     7.59
# 2015-01-05  2015-01-05     6.51    10.43
#
#                                             summary               desc  \
# Month
# 2015-01-01       Possible light rain until evening.               rain
# 2015-01-02  Possible light rain throughout the day.               rain
# 2015-01-03                Clear throughout the day.               rain
# 2015-01-04        Mostly cloudy throughout the day.  partly-cloudy-day
# 2015-01-05             Overcast throughout the day.  partly-cloudy-day
#
#             cloudCover  humidity  windSpeed  visibility
# Month
# 2015-01-01        0.80      0.89      14.69        4.43
# 2015-01-02        0.62      0.79      15.04        5.64
# 2015-01-03        0.31      0.84       4.48        6.20
# 2015-01-04        0.78      0.85       4.35        6.22
# 2015-01-05        0.85      0.91       6.20        5.91

# %%
del data['day']

# %%
data.head()
# Out:
#             tempMin  tempMax                                  summary  \
# Month
# 2015-01-01     7.53    12.23       Possible light rain until evening.
# 2015-01-02     3.58     7.15  Possible light rain throughout the day.
# 2015-01-03    -0.61     6.54                Clear throughout the day.
# 2015-01-04    -0.63     7.59        Mostly cloudy throughout the day.
# 2015-01-05     6.51    10.43             Overcast throughout the day.
#
#                          desc  cloudCover  humidity  windSpeed  visibility
# Month
# 2015-01-01               rain        0.80      0.89      14.69        4.43
# 2015-01-02               rain        0.62      0.79      15.04        5.64
# 2015-01-03               rain        0.31      0.84       4.48        6.20
# 2015-01-04  partly-cloudy-day        0.78      0.85       4.35        6.22
# 2015-01-05  partly-cloudy-day        0.85      0.91       6.20        5.91

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1795 entries, 2015-01-01 to 2019-11-30
# Data columns (total 8 columns):
# tempMin       1795 non-null float64
# tempMax       1795 non-null float64
# summary       1788 non-null object
# desc          1611 non-null object
# cloudCover    1792 non-null float64
# humidity      1795 non-null float64
# windSpeed     1795 non-null float64
# visibility    1795 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 126.2+ KB

# %%
data.desc.fillna(method='ffill',inplace=True)

# %%
data.cloudCover.fillna(method='ffill',inplace=True)

# %%
data.isnull().sum()
# Out:
# day           0
# tempMin       0
# tempMax       0
# summary       7
# desc          0
# cloudCover    0
# humidity      0
# windSpeed     0
# visibility    0
# dtype: int64

# %%
data=data.drop(columns=['desc'])

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomp = seasonal_decompose(x=data['tempMax'], model='additive')
est_trend = decomp.trend
est_seasonal = decomp.seasonal
est_residual = decomp.resid

# %%
fig, axes = plt.subplots(4, 1)
fig.set_figheight(10)
fig.set_figwidth(15)
axes[0].plot(data['tempMax'], label='Original')
axes[0].legend()
axes[1].plot(est_trend, label='Trend',color="b")
axes[1].legend()
axes[2].plot(est_seasonal, label='Seasonality',color='r')
axes[2].legend()
axes[3].plot(est_residual, label='Residuals',color='g')
axes[3].plot(est_c, label='Residuals',color='g')
axes[3].legend()

# %%
data_array = np.array(data['tempMax'])
partitions = np.split(data_array, indices_or_sections=1)
print("Mean of Partitions")
np.mean(partitions, axis=1)
print("-"*20)
print("Variance of Partitions")
np.var(partitions, axis=1)
# Out:
# Mean of Partitions
# --------------------
# Variance of Partitions
# array([27.7612008])

# %%
pd.Series(data_array).hist()

# %%
from statsmodels.tsa.stattools import adfuller
adf, pvalue, usedlag, nobs, critical_values, icbest = adfuller(data_array)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
ss_decomposition = seasonal_decompose(x=data_array, model='additive',freq=12)
est_trend = ss_decomposition.trend
est_seasonal = ss_decomposition.seasonal
est_residual = ss_decomposition.resid

# %%
print(est_trend)
print(est_seasonal)
print(est_residual)
# Out:
# [nan nan nan ... nan nan nan]
# [-0.07345123 -0.07572102  0.10257572 ... -0.00788318  0.06926209
#  -0.01518221]
# [nan nan nan ... nan nan nan]

# %%
new_adf, new_pvalue, usedlag_, nobs_, critical_values_, icbest_ = adfuller(est_residual[6:-6])
print("New ADF : ", new_adf)
print("Critical Values: ", critical_values_)
print("New P-value: ", new_pvalue)
# Out:
# New ADF :  -16.90772952337277
# Critical Values:  {'1%': -3.4340751843300223, '5%': -2.8631854615325496, '10%': -2.5676459942198253}
# New P-value:  1.0162257583188981e-29

# %%
from statsmodels.tsa.arima_model import ARIMA
# fitting the model on the 96 values
# removing the 12 NaN's values 
model = ARIMA(data_array[6:-6], order=(9,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                 1782
# Model:                 ARIMA(9, 1, 0)   Log Likelihood               -3958.101
# Method:                       css-mle   S.D. of innovations              2.230
# Date:                Sun, 01 Dec 2019   AIC                           7938.202
# Time:                        01:35:26   BIC                           7998.543
# Sample:                             1   HQIC                          7960.488
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.021     -0.036      0.971      -0.042       0.040
# ar.L1.D.y     -0.2718      0.024    -11.491      0.000      -0.318      -0.225
# ar.L2.D.y     -0.2647      0.024    -10.849      0.000      -0.313      -0.217
# ar.L3.D.y     -0.1970      0.025     -7.881      0.000      -0.246      -0.148
# ar.L4.D.y     -0.2116      0.025     -8.371      0.000      -0.261      -0.162
# ar.L5.D.y     -0.1637      0.025     -6.428      0.000      -0.214      -0.114
# ar.L6.D.y     -0.1268      0.025     -5.009      0.000      -0.176      -0.077
# ar.L7.D.y     -0.1353      0.025     -5.408      0.000      -0.184      -0.086
# ar.L8.D.y     -0.1038      0.024     -4.249      0.000      -0.152      -0.056
# ar.L9.D.y     -0.0648      0.024     -2.730      0.006      -0.111      -0.018
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0248           -0.6578j            1.2178           -0.0908
# AR.2            1.0248           +0.6578j            1.2178            0.0908
# AR.3            0.4647           -1.2192j            1.3047           -0.1920
# AR.4            0.4647           +1.2192j            1.3047            0.1920
# AR.5           -0.4459           -1.3440j            1.4160           -0.3010
# AR.6           -0.4459           +1.3440j            1.4160            0.3010
# AR.7           -1.4490           -0.0000j            1.4490           -0.5000
# AR.8           -1.1200           -0.9215j            1.4503           -0.3904
# AR.9           -1.1200           +0.9215j            1.4503            0.3904
# -----------------------------------------------------------------------------
#                  0
# count  1782.000000
# mean     -0.001516
# std       2.231478
# min      -9.901704
# 25%      -1.349255
# 50%      -0.085228
# 75%       1.389408
# max       7.890564
